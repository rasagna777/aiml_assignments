# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
data1 = pd.read_csv("NewspaperData.csv")
data1
# Out:
#                          Newspaper     daily    sunday
# 0                    Baltimore Sun   391.952   488.506
# 1                     Boston Globe   516.981   798.298
# 2                    Boston Herald   355.628   235.084
# 3               Charlotte Observer   238.555   299.451
# 4                Chicago Sun Times   537.780   559.093
# 5                  Chicago Tribune   733.775  1133.249
# 6              Cincinnati Enquirer   198.832   348.744
# 7                      Denver Post   252.624   417.779
# 8              Des Moines Register   206.204   344.522
# 9                 Hartford Courant   231.177   323.084
# 10               Houston Chronicle   449.755   620.752
# 11                Kansas City Star   288.571   423.305
# 12         Los Angeles Daily  News   185.736   202.614
# 13               Los Angeles Times  1164.388  1531.527
# 14                    Miami Herald   444.581   553.479
# 15        Minneapolis Star Tribune   412.871   685.975
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 948.0+ bytes

# %%
data1.describe()
# Out:
#              daily       sunday
# count    34.000000    34.000000
# mean    430.962471   591.202412
# std     269.211470   376.418051
# min     133.239000   202.614000
# 25%     233.021500   327.769500
# 50%     355.235500   436.712500
# 75%     516.616500   699.735250
# max    1209.225000  1762.015000

# %%
print(type(data1))
print(data1.shape)
print(data1.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (34, 3)
# 102

# %%
plt.figure(figsize=(14, 10))

# Boxplot
plt.subplot(2, 2, 1)
sns.boxplot(y=data1['daily'])
plt.title('Boxplot of Daily Circulation')

# Histogram
plt.subplot(2, 2, 2)
sns.histplot(data1['daily'], kde=False, bins=15)
plt.title('Histogram of Daily Circulation')

# KDE Plot
plt.subplot(2, 2, 3)
sns.kdeplot(data1['daily'])
plt.title('KDE Plot of Daily Circulation')

# Show plots
plt.tight_layout()
plt.show()

# %%
plt.scatter(data1["daily"], data1["sunday"])

# %%
#build regression model
import statsmodels.formula.api as smf
model = smf.ols("sunday~daily",data = data1).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 sunday   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     358.5
# Date:                Mon, 03 Feb 2025   Prob (F-statistic):           6.02e-19
# Time:                        09:31:21   Log-Likelihood:                -206.85
# No. Observations:                  34   AIC:                             417.7
# Df Residuals:                      32   BIC:                             420.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.8356     35.804      0.386      0.702     -59.095      86.766
# ...

# %%
x = data1["daily"].values
y = data1["sunday"].values
plt.scatter(x, y, color = "m", marker = "o", s = 30)
b0 = 13.84
b1 = 1.33
#predicted response vector
y_hat = b0 + b1*x
#plotting the regression line
plt.plot(x, y_hat, color = "g")
#putting labels
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **Observations**
# - There are no missing values
# - The daily column values appears to be right-skewed
# - The sunday column value also appear to be right-skewed
# - There are two oytliers in both daily column and also in sunday column as observed from the boxplot

# %% [markdown]
# **Scatter plot and Correlation Strength**

# %%
x=data1["daily"]
y=data1["sunday"]
plt.scatter(data1["daily"], data1["sunday"])
plt.xlim(0, max(x) + 100)
plt.ylim(0, max(y) + 100)
plt.show()

# %%
data1.corr(numeric_only=True)
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %% [markdown]
# #### Observation on Correlation strength
# - The relationship between x(daily) and y(sunday) is seen to be linear as seen from scatter plot
# - The correlation is strong and positive with Person's correlation coefficient of 0.958154

# %% [markdown]
# #### Fit Linear Regression Model

# %%
#build regression model
import statsmodels.formula.api as smf
model1 = smf.ols("sunday~daily",data = data1).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 sunday   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.915
# Method:                 Least Squares   F-statistic:                     358.5
# Date:                Mon, 03 Feb 2025   Prob (F-statistic):           6.02e-19
# Time:                        09:31:34   Log-Likelihood:                -206.85
# No. Observations:                  34   AIC:                             417.7
# Df Residuals:                      32   BIC:                             420.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.8356     35.804      0.386      0.702     -59.095      86.766
# ...

# %% [markdown]
# #### Obersvations
# - Beta_0 , Beta_1
# - predicted equation is y_hat = beta_0 + beta_1X
# - y_hat = 13.8356 + 1.3397x
# - The probability(p-value) for interecept (beta_0) is 0.707 > 0.05
# - Therefore, the intercept coeffiecient may not be that much significant in prediction
# - However, the p-value for "daily"(beta_1) is 0.00 < 0.05
# - Therefore, the beta_1 coefficient is highly significant and is contributing to prediction

# %%
model1.params
# Out:
# Intercept    13.835630
# daily         1.339715
# dtype: float64

# %%
#Print the fitted line coefficients (beta_0 and beta_1)
model1.params
# Out:
# Intercept    13.835630
# daily         1.339715
# dtype: float64

# %%
#print the model  statistics (t and p-Values)
print(f'model t-values:\n{model1.tvalues}\n--------------\n{model1.pvalues}')
# Out:
# model t-values:
# Intercept     0.386427
# daily        18.934840
# dtype: float64
# --------------
# Intercept    7.017382e-01
# daily        6.016802e-19
# dtype: float64

# %%
#print the quality of fitted line(R squared values)
model1.rsquared,model1.rsquared_adj
# Out:
# (0.9180596895873295, 0.9154990548869336)

# %%
#predict for 200 and 300 daily circulation
newdata=pd.Series([200,300,1500])

# %%
data_pred=pd.DataFrame(newdata,columns=['daily'])
data_pred
# Out:
#    daily
# 0    200
# 1    300
# 2   1500

# %%
model1.predict(data_pred)
# Out:
# 0     281.778581
# 1     415.750057
# 2    2023.407766
# dtype: float64

# %%
#predict on given all training data
pred = model1.predict(data1["daily"])
pred
# Out:
# 0      538.939509
# 1      706.442705
# 2      490.275710
# 3      333.431284
# 4      734.307432
# 5      996.884826
# 6      280.213795
# 7      352.279731
# 8      290.090172
# 9      323.546868
# 10     616.379041
# 11     400.438457
# 12     262.668890
# 13    1573.783417
# 14     609.447357
# 15     566.965002
# 16     378.613164
# 17    1061.219269
# 18    1633.852208
# 19    1119.786239
# 20     313.594128
# 21     489.224034
# 22     704.489401
# 23     309.195844
# 24     466.219792
# 25     277.920203
# 26     192.337885
# 27     514.901007
# 28     380.708478
# 29     777.960698
# 30     538.047259
# 31     284.270451
# 32     444.722729
# 33    1137.725020
# dtype: float64

# %%
#add predicted values as a column in data1
data1["Y_hat"] = pred
data1
# Out:
#                          Newspaper     daily    sunday        Y_hat
# 0                    Baltimore Sun   391.952   488.506   538.939509
# 1                     Boston Globe   516.981   798.298   706.442705
# 2                    Boston Herald   355.628   235.084   490.275710
# 3               Charlotte Observer   238.555   299.451   333.431284
# 4                Chicago Sun Times   537.780   559.093   734.307432
# 5                  Chicago Tribune   733.775  1133.249   996.884826
# 6              Cincinnati Enquirer   198.832   348.744   280.213795
# 7                      Denver Post   252.624   417.779   352.279731
# 8              Des Moines Register   206.204   344.522   290.090172
# 9                 Hartford Courant   231.177   323.084   323.546868
# 10               Houston Chronicle   449.755   620.752   616.379041
# 11                Kansas City Star   288.571   423.305   400.438457
# 12         Los Angeles Daily  News   185.736   202.614   262.668890
# ...

# %%
#compute the error values (residuals) and add as another column
data1["residuals"] = data1["sunday"]-data1["Y_hat"]
data1
# Out:
#                          Newspaper     daily    sunday        Y_hat  \
# 0                    Baltimore Sun   391.952   488.506   538.939509
# 1                     Boston Globe   516.981   798.298   706.442705
# 2                    Boston Herald   355.628   235.084   490.275710
# 3               Charlotte Observer   238.555   299.451   333.431284
# 4                Chicago Sun Times   537.780   559.093   734.307432
# 5                  Chicago Tribune   733.775  1133.249   996.884826
# 6              Cincinnati Enquirer   198.832   348.744   280.213795
# 7                      Denver Post   252.624   417.779   352.279731
# 8              Des Moines Register   206.204   344.522   290.090172
# 9                 Hartford Courant   231.177   323.084   323.546868
# 10               Houston Chronicle   449.755   620.752   616.379041
# 11                Kansas City Star   288.571   423.305   400.438457
# 12         Los Angeles Daily  News   185.736   202.614   262.668890
# ...

# %%
#compute Mean Squared Error for the model
mse = np.mean((data1["daily"]-data1["Y_hat"])**2)
rmse = np.sqrt(mse)
print("MSE: ",mse)
print("RMSE: ",rmse)
# Out:
# MSE:  33794.87469205264
# RMSE:  183.8338235800274

# %% [markdown]
# #### Checking the model residuala distribution

# %%
#plot the residuals vs y_hat (to check whether residuals are independent of each other)
plt.scatter(data1["Y_hat"], data1["residuals"])

# %% [markdown]
# #### Observations
#  - There appears to be trend and the residuals are randomly placed around the zero error line
#  - Hence the assumption of homoscedansticty is satisfied (constant variance in residuals)

# %%
#Plot the Q-Q plot(to check the normality of rsiduals)
import
